# %%
import pickle

filename = "data_2025-05-13_10_55.pkl"
with open(filename, "rb") as file:
    data = pickle.load(file)

# %%
data["model"].coef_
# Out:
# array([[ 5.59053592e-01, -7.36506000e-05,  1.60844113e-05,
#          1.30948428e+06, -1.33355857e+05, -5.28243563e+06,
#          1.15000432e+07, -1.47744069e+07,  1.13866831e+07,
#          7.87106402e-04, -5.04312929e+06,  2.15986850e-03,
#          3.81737226e-04,  1.11900915e+06, -2.30669883e-03,
#         -1.38203312e-03, -4.04633441e+04, -4.17417484e+04,
#         -9.13984070e-04, -3.26535466e-04,  4.86735934e-03,
#         -3.26818790e-03, -5.86758199e-04,  3.13931890e-04,
#         -1.71980883e+00,  3.65359197e-01,  3.06441904e+00,
#         -2.48907923e+00,  1.82399804e-03, -1.34272221e-03,
#          6.96568384e-04, -1.37856302e-04, -3.96767802e-05,
#          1.73879145e-04,  9.26409375e-01, -2.04945687e-04,
#          5.74797937e-05,  3.79241564e-05, -3.53977015e-04,
#          6.24041150e-02,  8.15539788e-05,  6.36557594e-05,
#          2.84600518e-04, -1.51995541e-01,  2.28047042e-06,
#          1.53422358e-04,  4.26604354e-06],
# ...
