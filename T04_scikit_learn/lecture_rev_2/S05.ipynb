# %%
import pickle
from datetime import datetime
from pprint import pp

import pandas as pd
from sklearn.base import BaseEstimator
from sklearn.model_selection import train_test_split

# %%
class RegSwitcher(BaseEstimator):
    def __init__(self, base=None):
        self.base = base

    def fit(self, X, Y):
        self.base.fit(X, Y)
        self.is_fitted_ = True
        return self

    def predict(self, X):
        return self.base.predict(X)

# %%
class MyUtil:
    def save_data(filename, data):
        with open(filename, "wb") as file:
            pickle.dump(data, file)

    def load_data(filename):
        with open(filename, "rb") as file:
            data = pickle.load(file)
        return data

    def get_dt():
        return datetime.now().strftime("%Y-%m-%d_%H-%M")

# %%
class DataHandler():
    def __init__(self, _X, _Y, scalerX, scalerY):
        self._X = _X
        self._Y = _Y
        self.scalerX = scalerX
        self.scalerY = scalerY
        self.X_train = None
        self.X_test = None
        self.Y_train = None
        self.Y_test = None

    def split_and_scale(self, test_size, random_state):
        _X_train, _X_test, _Y_train, _Y_test = train_test_split(
            self._X, self._Y, test_size=test_size, random_state=random_state
        )
        self.X_train = self.scalerX.fit_transform(_X_train)
        self.X_test = self.scalerX.transform(_X_test)

        self.Y_train = self.scalerY.fit_transform(_Y_train)
        self.Y_test = self.scalerY.transform(_Y_test)

    def get_train(self):
        return self.X_train, self.Y_train

    def get_test(self):
        return self.X_test, self.Y_test

# %%
import pickle

with open("S04_data_2025-05-16_10-43.pkl", "rb") as file:
    data = pickle.load(file)
data
# Out:
# {'desc': 'This is the saved data',
#  'data_handler': <__main__.DataHandler at 0x165e49f3ad0>,
#  'param_split': {'random_state': 5, 'test_size': 0.3},
#  'param_grid_hyper': [{'base': [MultiOutputRegressor(estimator=LinearRegression())]},
#   {'base': [MultiOutputRegressor(estimator=SVR())],
#    'base__estimator__C': [0.01, 0.1, 1]},
#   {'base': [MultiOutputRegressor(estimator=RandomForestRegressor())],
#    'base__estimator__n_estimators': [10, 50, 200]}],
#  'df_fit':     id_split                            param_split  id_gs  \
#  0          0  {'random_state': 1, 'test_size': 0.3}      0
#  1          0  {'random_state': 1, 'test_size': 0.3}      1
#  2          0  {'random_state': 1, 'test_size': 0.3}      2
#  3          0  {'random_state': 1, 'test_size': 0.3}      3
#  4          0  {'random_state': 1, 'test_size': 0.3}      4
#  5          0  {'random_state': 1, 'test_size': 0.3}      5
#  6          0  {'random_state': 1, 'test_size': 0.3}      6
#  7          1  {'random_state': 2, 'test_size': 0.3}      0
#  8          1  {'random_state': 2, 'test_size': 0.3}      1
#  9          1  {'random_state': 2, 'test_size': 0.3}      2
#  10         1  {'random_state': 2, 'test_size': 0.3}      3
#  11         1  {'random_state': 2, 'test_size': 0.3}      4
#  12         1  {'random_state': 2, 'test_size': 0.3}      5
#  13         1  {'random_state': 2, 'test_size': 0.3}      6
#  14         2  {'random_state': 3, 'test_size': 0.3}      0
#  15         2  {'random_state': 3, 'test_size': 0.3}      1
#  16         2  {'random_state': 3, 'test_size': 0.3}      2
#  17         2  {'random_state': 3, 'test_size': 0.3}      3
#  18         2  {'random_state': 3, 'test_size': 0.3}      4
#  19         2  {'random_state': 3, 'test_size': 0.3}      5
#  20         2  {'random_state': 3, 'test_size': 0.3}      6
#  21         3  {'random_state': 4, 'test_size': 0.3}      0
#  22         3  {'random_state': 4, 'test_size': 0.3}      1
#  23         3  {'random_state': 4, 'test_size': 0.3}      2
#  24         3  {'random_state': 4, 'test_size': 0.3}      3
#  25         3  {'random_state': 4, 'test_size': 0.3}      4
#  26         3  {'random_state': 4, 'test_size': 0.3}      5
#  27         3  {'random_state': 4, 'test_size': 0.3}      6
#  28         4  {'random_state': 5, 'test_size': 0.3}      0
#  29         4  {'random_state': 5, 'test_size': 0.3}      1
#  30         4  {'random_state': 5, 'test_size': 0.3}      2
#  31         4  {'random_state': 5, 'test_size': 0.3}      3
#  32         4  {'random_state': 5, 'test_size': 0.3}      4
#  33         4  {'random_state': 5, 'test_size': 0.3}      5
#  34         4  {'random_state': 5, 'test_size': 0.3}      6
#
#                                                 params              estimator  \
#  0   {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
#  1   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  2   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  3   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  4   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  5   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  6   {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  7   {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
#  8   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  9   {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  10  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  11  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  12  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  13  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  14  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
#  15  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  16  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  17  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  18  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  19  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  20  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  21  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
#  22  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  23  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  24  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  25  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  26  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  27  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  28  {'base': MultiOutputRegressor(estimator=Linear...       LinearRegression
#  29  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  30  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  31  {'base': MultiOutputRegressor(estimator=SVR())...                    SVR
#  32  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  33  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#  34  {'base': MultiOutputRegressor(estimator=Random...  RandomForestRegressor
#
#      mean_test_score  std_test_score  rank_test_score
#  0         -2.372222        3.924419                7
#  1         -0.006503        0.027330                6
#  2          0.304896        0.003312                5
#  3          0.744229        0.089645                4
#  4          0.781687        0.050280                1
#  5          0.765502        0.059094                3
#  6          0.774352        0.064975                2
#  7         -1.937197        3.212609                7
#  8          0.011377        0.037278                6
#  9          0.304724        0.042627                5
#  10         0.703175        0.050213                4
#  11         0.753030        0.080876                1
#  12         0.737934        0.098191                3
#  13         0.747131        0.086334                2
#  14        -6.095767        8.482891                7
#  15        -0.080060        0.161918                6
#  16         0.263339        0.047776                5
#  17         0.753062        0.044288                1
#  18         0.715146        0.115397                4
#  19         0.737550        0.073536                3
#  20         0.743303        0.059383                2
#  21        -4.400783        7.369193                7
#  22         0.014877        0.005231                6
#  23         0.306944        0.036002                5
#  24         0.779790        0.055770                1
#  25         0.702295        0.039085                4
#  26         0.752350        0.026112                2
#  27         0.743809        0.030402                3
#  28        -3.719301        5.063474                7
#  29        -0.094212        0.055550                6
#  30         0.193186        0.056759                5
#  31         0.647932        0.003962                4
#  32         0.678305        0.049591                3
#  33         0.724284        0.016482                2
#  34         0.736449        0.021907                1  }
